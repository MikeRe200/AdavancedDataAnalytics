# %%
import pandas as pd

from sqlalchemy import create_engine

# %%
# Connect to sqlite db
db_file = r'datasets/database.sqlite'
engine = create_engine(r"sqlite:///{}".format(db_file))

# %%
# Connect to sqlite db
db_file = r'datasets/database.sqlite'
engine = create_engine(r"sqlite:///{}".format(db_file))

# %%
#find out what tables are in the database
sql = "SELECT * FROM sqlite_master WHERE type = 'table';"

table_names = pd.read_sql(sql, engine)
table_names
# Out:
#     type                      name                  tbl_name  rootpage  \
# 0  table                BoardGames                BoardGames         2
# 1  table         bgg.ldaOut.topics         bgg.ldaOut.topics    128639
# 2  table      bgg.ldaOut.top.terms      bgg.ldaOut.top.terms    129442
# 3  table  bgg.ldaOut.top.documents  bgg.ldaOut.top.documents    129454
# 4  table                bgg.topics                bgg.topics    129468
#
#                                                  sql
# 0  CREATE TABLE "BoardGames" (\n  "row_names" TEX...
# 1  CREATE TABLE "bgg.ldaOut.topics" (\n  "row_nam...
# 2  CREATE TABLE "bgg.ldaOut.top.terms" (\n  "row_...
# 3  CREATE TABLE "bgg.ldaOut.top.documents" (\n  "...
# 4  CREATE TABLE "bgg.topics" (\n  "row_names" TEX...

# %%
#Count number of rows in one column
sql = "SELECT COUNT(*) as RowCount FROM BoardGames "

RowCount = pd.read_sql(sql, engine)
RowCount
# Out:
#    RowCount
# 0     90400

# %%
#get everything from table BoardGames    
sql = "SELECT * FROM BoardGames;"
sales_data_df = pd.read_sql(sql, engine)
sales_data_df

# %%
#Number of Column of table BoardGames
len(sales_data_df.columns)
# Out:
# 81

# %%
#get everything from table BoardGames    
sql2 = "SELECT * FROM 'bgg.ldaOut.topics';"
sales_data_df = pd.read_sql(sql2, engine)
sales_data_df.head()
# Out:
#         row_names  topics(bgg.ldaOut)
# 0      Die.Macher                   8
# 1    Dragonmaster                   5
# 2         Samurai                  22
# 3  Tal.der.Könige                   4
# 4         Acquire                   4

# %%
#Count number of rows in one column
sql2 = "SELECT COUNT(*) as RowCount FROM 'bgg.ldaOut.topics';"

RowCount = pd.read_sql(sql2, engine)
RowCount
# Out:
#    RowCount
# 0     29229

# %%
#Number of Column of table BoardGames
len(sales_data_df.columns)
# Out:
# 74

# %%
#get everything from table BoardGames    
sql2 = "SELECT * FROM 'bgg.ldaOut.top.term';"
sales_data_df = pd.read_sql(sql2, engine)
sales_data_df.head()

# %%
#get everything from table BoardGames    
sql2 = "SELECT * FROM 'bgg.ldaOut.top.documents';"
sales_data_df = pd.read_sql(sql2, engine)
sales_data_df.head()
# Out:
#   row_names                                           document  topic  \
# 0         1                           The.Lounge..A.Mafia.Game      1
# 1         2                Ultimate.Werewolf..Ultimate.Edition      1
# 2         3  Ultimate.Werewolf..Deluxe.Edition.For.Kickstarter      1
# 3         4                                           Werewolf      1
# 4         5                     Παλέρμο..Το.Μεγάλο.Ξεκαθάρισμα      1
#
#       gamma
# 0  0.203125
# 1  0.200000
# 2  0.200000
# 3  0.194805
# 4  0.190476

# %%
##################################################################################################################################

# %%
#get everything from table BoardGames    
sql2 = "SELECT * FROM 'bgg.topics';"
sales_data_df = pd.read_sql(sql2, engine)
sales_data_df.head()
# Out:
#   row_names game.id  game.type  details.maxplayers  details.maxplaytime  \
# 0         1       1  boardgame                 5.0                240.0
# 1         2       2  boardgame                 4.0                 30.0
# 2         3       3  boardgame                 4.0                 60.0
# 3         4       4  boardgame                 4.0                 60.0
# 4         5       5  boardgame                 6.0                 90.0
#
#    details.minage  details.minplayers  details.minplaytime    details.name  \
# 0            14.0                 3.0                240.0      Die Macher
# 1            12.0                 3.0                 30.0    Dragonmaster
# 2            10.0                 2.0                 30.0         Samurai
# 3            12.0                 2.0                 60.0  Tal der Könige
# 4            12.0                 3.0                 90.0         Acquire
#
#    details.playingtime            ...             \
# ...

# %%
for i in table_names:
    print(i)
# Out:
# type
# name
# tbl_name
# rootpage
# sql

# %%
for i in table_names['name']:
    print(i)
# Out:
# BoardGames
# bgg.ldaOut.topics
# bgg.ldaOut.top.terms
# bgg.ldaOut.top.documents
# bgg.topics

# %%
for i in table_names['name']:
    #print(i)
    if i == 'BoardGames':
        BoardGames=i
        dsql1= "SELECT * FROM "+BoardGames+';'
        BoardGamesData= pd.read_sql(dsql1, engine)
        #print(BoardGamesData.head())
        #print(dsql1)
    if i == 'bgg.ldaOut.topics':
        topics=i
        dsql2= "SELECT * FROM "+'topics'+';'
        print(dsql2)
        TopicData=pd.read_sql(dsql2, engine)
        #print(TopicData.head())
# Out:
# SELECT * FROM topics;
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\Anaconda\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\Anaconda\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# OperationalError: no such table: topics
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-66-8170a80d6188> in <module>
# ...

# %%
topics
# Out:
# 'bgg.ldaOut.topics'

# %%
#example
table='Canvas'
dsql= "SELECT * FROM"+' '+ table+';'
print(dsql)
# Out:
# SELECT * FROM Canvas;

# %%
#get everything from table BoardGames 
table_name= "BoardGames"
Dsql= "SELECT * FROM "+ table_name+";"
#print(Dsql)
sales_data_df = pd.read_sql(Dsql, engine)
sales_data_df.head()
# Out:
#   row_names game.id  game.type  \
# 0         1       1  boardgame
# 1         2       2  boardgame
# 2         3       3  boardgame
# 3         4       4  boardgame
# 4         5       5  boardgame
#
#                                  details.description  \
# 0  Die Macher is a game about seven sequential po...
# 1  Dragonmaster is a trick-taking card game based...
# 2  Part of the Knizia tile-laying trilogy, Samura...
# 3  When you see the triangular box and the luxuri...
# 4  In Acquire, each player strategically invests ...
#
#                                   details.image  details.maxplayers  \
# 0   //cf.geekdo-images.com/images/pic159509.jpg                 5.0
# 1   //cf.geekdo-images.com/images/pic184174.jpg                 4.0
# 2  //cf.geekdo-images.com/images/pic3211873.jpg                 4.0
# 3   //cf.geekdo-images.com/images/pic285299.jpg                 4.0
# 4   //cf.geekdo-images.com/images/pic342163.jpg                 6.0
#
# ...

# %%
for i in table_names['name']:

    #get everything from table BoardGames 
    table_name= i
    Dsql= "SELECT * FROM "+ table_name+";"
    print(Dsql)
    if i== 'BoardGames':
        sales_data_df = pd.read_sql(Dsql, engine)
    elif i=="'bgg.ldaOut.topics'":
        Topics = pd.read_sql(Dsql, engine)
# Out:
# SELECT * FROM BoardGames;
# SELECT * FROM bgg.ldaOut.topics;
# SELECT * FROM bgg.ldaOut.top.terms;
# SELECT * FROM bgg.ldaOut.top.documents;
# SELECT * FROM bgg.topics;

# %%
print(Topics)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-b7ba81ddec8b> in <module>
# ----> 1 print(Topics)
#
# NameError: name 'Topics' is not defined
